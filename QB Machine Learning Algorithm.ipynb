# %%
from sklearn import tree
import pandas as pd
import os

# %%
QB_data = pd.read_csv("../nfl-project3/QB Machine Learning.csv")

# %%
QB_data = QB_data.loc[QB_data["Touches"] > 0]
del QB_data["VertLeap"]
del QB_data["BenchPress"]
del QB_data["ThreeCone"]
del QB_data["Shuttle"]
del QB_data["Arm Length"]
del QB_data["BroadJump"]
del QB_data["BroadJump"]
QB_data
# Out:
#      Height  Weight  Hand Size  Wonderlic  FortyYard  Touches   Pct   Y_A  \
# 0    70.625     204      10.25       28.0       4.53     1930  60.9   7.9
# 1    77.000     248       9.88       21.0       4.56      577  65.4  10.0
# 2    74.250     226      10.88        NaN       4.79     1705  62.8   8.0
# 3    76.750     228       9.50       32.0       4.94     1515  59.9   6.9
# 4    78.380     236       9.63       27.0       4.86       10  25.0   2.8
# ..      ...     ...        ...        ...        ...      ...   ...   ...
# 307  77.000     253       9.75        NaN       4.81      422  61.7   8.6
# 308  76.375     223       9.00        NaN       4.78     1443  56.1   6.8
# 309  76.000     217       9.75        NaN       4.79     1346  57.5   7.9
# 310  75.000     207        NaN        NaN        NaN     1272  61.7   7.3
# 311  75.750     229      10.00       35.0       4.86     1822  55.5   7.3
#
#      PassTDPct  IntPct  RushTDPct  RushAvg  RookieAV
# ...

# %%
target = QB_data["RookieAV"]

# %%
data = QB_data.drop("RookieAV", axis=1)
data.fillna(data.mean(), inplace=True)
feature_names = data.columns
data.head()
# Out:
#    Height  Weight  Hand Size  Wonderlic  FortyYard  Touches   Pct   Y_A  \
# 0  70.625     204      10.25  28.000000       4.53     1930  60.9   7.9
# 1  77.000     248       9.88  21.000000       4.56      577  65.4  10.0
# 2  74.250     226      10.88  27.028777       4.79     1705  62.8   8.0
# 3  76.750     228       9.50  32.000000       4.94     1515  59.9   6.9
# 4  78.380     236       9.63  27.000000       4.86       10  25.0   2.8
#
#    PassTDPct  IntPct  RushTDPct  RushAvg
# 0      0.073   0.020      0.052      3.2
# 1      0.103   0.024      0.084      5.6
# 2      0.060   0.020      0.076      4.7
# 3      0.042   0.027      0.065      0.3
# 4      0.000   0.000      0.000      0.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# -0.9516100149768831

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=10000)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.0817541661352621

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.16324058718018747, 'Height'),
#  (0.12327512625495464, 'FortyYard'),
#  (0.11713495074257618, 'Wonderlic'),
#  (0.08329908670492896, 'RushTDPct'),
#  (0.08245003839652096, 'Hand Size'),
#  (0.07676851773968198, 'Pct'),
#  (0.06957005057507877, 'RushAvg'),
#  (0.06716990986341519, 'PassTDPct'),
#  (0.06272570343188014, 'Touches'),
#  (0.0543115997474178, 'Weight'),
#  (0.05384215212740691, 'Y_A'),
#  (0.04621227723595114, 'IntPct')]

# %%
row = [[74.125, 225, 9.25, 24, 4.8, 1657, 63.5, 8.3, .069, .021, .071, 2.7]]
yhat = rf.fit(X_train, y_train).predict(row)
print('Prediction: %d' % yhat[0])
# Out:
# Prediction: 0
