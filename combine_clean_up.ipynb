# %%
import pandas as pd

# %%
combine_data = pd.read_csv("../nfl-project3/Combine_Data.csv")
combine_data.head()
# Out:
#    Year             Name           College  POS  Height (in)  Weight (lbs)  \
# 0  2002    Aaron Lockett        Kansas St.   WR         67.4           155
# 1  2002    Abdual Howard       Florida St.   SS         72.0           209
# 2  2002  Adrian Peterson  Georgia Southern   RB         70.0           214
# 3  2002     Akin Ayodele            Purdue  OLB         74.1           257
# 4  2002      Alan Harper        Fresno St.   DT         73.9           295
#
#    Hand Size (in)  Arm Length (in)  40 Yard  Bench Press  Vert Leap (in)  \
# 0            7.13            29.00     4.34          NaN            35.0
# 1           10.25            30.75     4.63          NaN             NaN
# 2            9.75            31.75     4.69         14.0            34.0
# 3            9.75            32.50     4.86         26.0            35.0
# 4           10.25            31.50     5.31          NaN            30.5
#
#    Broad Jump (in)  Shuttle  3Cone  60Yd Shuttle
# ...

# %%
combine_data = combine_data.fillna(0)

# %%
combine_data.head()
# Out:
#    Year             Name           College  POS  Height (in)  Weight (lbs)  \
# 0  2002    Aaron Lockett        Kansas St.   WR         67.4           155
# 1  2002    Abdual Howard       Florida St.   SS         72.0           209
# 2  2002  Adrian Peterson  Georgia Southern   RB         70.0           214
# 3  2002     Akin Ayodele            Purdue  OLB         74.1           257
# 4  2002      Alan Harper        Fresno St.   DT         73.9           295
#
#    Hand Size (in)  Arm Length (in)  40 Yard  Bench Press  Vert Leap (in)  \
# 0            7.13            29.00     4.34          0.0            35.0
# 1           10.25            30.75     4.63          0.0             0.0
# 2            9.75            31.75     4.69         14.0            34.0
# 3            9.75            32.50     4.86         26.0            35.0
# 4           10.25            31.50     5.31          0.0            30.5
#
#    Broad Jump (in)  Shuttle  3Cone  60Yd Shuttle
# ...

# %%
combine_data.to_csv('clean_combine_data.csv', index=False)
